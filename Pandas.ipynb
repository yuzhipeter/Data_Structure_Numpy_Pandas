# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Data Input

# %%
dir = str(os.getcwd())+"\\"
df= pd.read_csv(dir + 'housepricedata.csv')
df.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
df.tail()
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0

# %%
dates = pd.date_range('20130101', periods=6)
df_1 = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df_1.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.279752  0.825110 -0.179268  1.273266
# 2013-01-02 -0.071436 -1.153604 -0.583213  0.518639
# 2013-01-03 -0.769644  0.052489  0.123291 -0.871593
# 2013-01-04  0.896123 -0.949654 -0.209544 -0.468921
# 2013-01-05 -0.713593 -2.801288 -1.145110 -1.731451

# %% [markdown]
# # View Data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
df_1.to_numpy()
# Out:
# array([[ 1.27975201,  0.82511035, -0.17926844,  1.27326622],
#        [-0.07143568, -1.153604  , -0.58321258,  0.518639  ],
#        [-0.76964388,  0.05248908,  0.12329133, -0.87159269],
#        [ 0.89612272, -0.94965412, -0.20954447, -0.46892148],
#        [-0.71359251, -2.80128814, -1.14511016, -1.73145066],
#        [-0.13611523,  1.07413804,  0.03492232,  0.15238218]])

# %%
df.describe()
# Out:
#              LotArea  OverallQual  OverallCond  TotalBsmtSF     FullBath  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082     6.099315     5.575342  1057.429452     1.565068
# std      9981.264932     1.382997     1.112799   438.705324     0.550916
# min      1300.000000     1.000000     1.000000     0.000000     0.000000
# 25%      7553.500000     5.000000     5.000000   795.750000     1.000000
# 50%      9478.500000     6.000000     5.000000   991.500000     2.000000
# 75%     11601.500000     7.000000     6.000000  1298.250000     2.000000
# max    215245.000000    10.000000     9.000000  6110.000000     3.000000
#
#           HalfBath  BedroomAbvGr  TotRmsAbvGrd   Fireplaces   GarageArea  \
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean      0.382877      2.866438      6.517808     0.613014   472.980137
# std       0.502885      0.815778      1.625393     0.644666   213.804841
# ...

# %%
df_1.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.279752   -0.071436   -0.769644    0.896123   -0.713593   -0.136115
# B    0.825110   -1.153604    0.052489   -0.949654   -2.801288    1.074138
# C   -0.179268   -0.583213    0.123291   -0.209544   -1.145110    0.034922
# D    1.273266    0.518639   -0.871593   -0.468921   -1.731451    0.152382

# %%
df.sort_values(by='LotArea')
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 956      1300            6            6          561         1         1
# 1039     1477            4            4          630         1         0
# 614      1491            4            6          630         1         0
# 489      1526            4            8          630         1         0
# 1449     1533            5            7          630         1         0
# ...       ...          ...          ...          ...       ...       ...
# 451     70761            7            5         1533         2         0
# 706    115149            7            5         1643         2         0
# 249    159000            6            7         1444         2         0
# 335    164660            5            6         1499         2         0
# 313    215245            7            5         2136         2         0
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
df.sort_index()
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %% [markdown]
# # Choose

# %%
df['Fireplaces']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1455    1
# 1456    2
# 1457    2
# 1458    0
# 1459    0
# Name: Fireplaces, Length: 1460, dtype: int64

# %%
df[100:200]
# Out:
#      LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 100    10603            6            7         1610         2         0
# 101     9206            6            5          741         2         1
# 102     7018            5            5            0         2         0
# 103    10402            7            5         1226         2         0
# 104     7758            7            4         1040         1         1
# ..       ...          ...          ...          ...       ...       ...
# 195     2280            6            6          855         2         1
# 196     9416            7            5         1726         2         0
# 197    25419            8            4         1360         2         0
# 198     5520            6            6          755         1         0
# 199     9591            8            5         1713         2         0
#
#      BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
df.loc[100:200,['LotArea','FullBath']]
# Out:
#      LotArea  FullBath
# 100    10603         2
# 101     9206         2
# 102     7018         2
# 103    10402         2
# 104     7758         1
# ..       ...       ...
# 196     9416         2
# 197    25419         2
# 198     5520         1
# 199     9591         2
# 200     8546         2
#
# [101 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# LotArea             8450
# OverallQual            7
# OverallCond            5
# TotalBsmtSF          856
# FullBath               2
# HalfBath               1
# BedroomAbvGr           3
# TotRmsAbvGrd           8
# Fireplaces             0
# GarageArea           548
# AboveMedianPrice       1
# Name: 0, dtype: int64

# %%
df.iloc[1,1]
# Out:
# 6

# %%
print (df.Fireplaces[0])
print (df.FullBath[0])
df.Fireplaces[0] + df.FullBath[0]
# Out:
# 0
# 2
# 2

# %% [markdown]
# Boolean Operation

# %%
df.FullBath.max()
# Out:
# 3

# %%
df[df.Fireplaces.idxmax(): df.Fireplaces.idxmax()+1]
# Out:
#      LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 166    10708            5            5         1617         1         0
#
#      BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 166             2             7           3         303                 1

# %%
len(df[df.FullBath > 2])
# Out:
# 33

# %%
df[df.FullBath > 2]
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 11      11924            9            5         1175         3         0
# 20      14215            8            5         1158         3         1
# 35      13418            8            5         1117         3         1
# 58      13682           10            5         1410         3         1
# 118     12376            7            5         1673         3         0
# 137     11070            7            5         1907         3         0
# 304     18386            7            9         1470         3         0
# 320     16259            9            5         1249         3         1
# 362      7301            7            5            0         3         0
# 377     11143            8            5         1580         3         0
# 496     12692            8            5         3200         3         0
# 523     40094           10            5         3138         3         1
# ...

# %%
df_1['E'] = ['one']*6
df_1.E[2] = 'zero'
df_1.head()
# Out:
# C:\Users\Peter\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    A         B         C         D     E
# 2013-01-01  1.279752  0.825110 -0.179268  1.273266   one
# 2013-01-02 -0.071436 -1.153604 -0.583213  0.518639   one
# 2013-01-03 -0.769644  0.052489  0.123291 -0.871593  zero
# 2013-01-04  0.896123 -0.949654 -0.209544 -0.468921   one
# 2013-01-05 -0.713593 -2.801288 -1.145110 -1.731451   one

# %%
df_1[df_1['E'].isin(['zero'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.769644  0.052489  0.123291 -0.871593  zero

# %% [markdown]
# Missing data

# %%
dates = pd.date_range('20130101', periods=6)
df_1 = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df_2 = df_1.reindex(index=dates[0:4], columns=list(df_1.columns) + ['E'])
df_2.loc[dates[0]:dates[1], 'E'] = 1
df_2
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.169071 -0.947177 -0.803331 -0.416543  1.0
# 2013-01-02 -0.521884  1.577085 -2.980708 -0.581255  1.0
# 2013-01-03  0.057308  1.181520 -0.261091  0.479195  NaN
# 2013-01-04  0.318226  0.583112 -0.865668  1.354803  NaN

# %% [markdown]
# # Drop missing data

# %%
df_2.dropna(how = 'any')
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.169071 -0.947177 -0.803331 -0.416543  1.0
# 2013-01-02 -0.521884  1.577085 -2.980708 -0.581255  1.0

# %% [markdown]
# Filling missing data

# %%
df_2.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.169071 -0.947177 -0.803331 -0.416543  1.0
# 2013-01-02 -0.521884  1.577085 -2.980708 -0.581255  1.0
# 2013-01-03  0.057308  1.181520 -0.261091  0.479195  5.0
# 2013-01-04  0.318226  0.583112 -0.865668  1.354803  5.0

# %% [markdown]
# Apply

# %%
df.apply(np.max)
# Out:
# Date                           2020-05-08 00:00:00
# ProShares Name              ProShares Short S&P500
# Ticker                                          SH
# NAV                                          207.4
# Prior NAV                                    207.4
# NAV Change (%)                             12.0044
# NAV Change ($)                               15.36
# Shares Outstanding (000)                    163131
# Assets Under Management                4.11621e+09
# dtype: object

# %% [markdown]
# # Rename Column

# %%
df_select = df[['LotArea','Fireplaces']]
df_select.head()
# Out:
#    LotArea  Fireplaces
# 0     8450           0
# 1     9600           1
# 2    11250           1
# 3     9550           1
# 4    14260           1

# %%
df_select = df_select.rename(columns = {"LotArea": "Lot Size","Fireplaces": "Fire places number"})
df_select.head()
# Out:
#    Lot Size  Fire places number
# 0      8450                   0
# 1      9600                   1
# 2     11250                   1
# 3      9550                   1
# 4     14260                   1

# %% [markdown]
# # Re Index

# %%
df_select = df_select.set_index('Lot Size')

# %%
#df_select = df_select.set_index('Lot Size')
df_select.head()
# Out:
#           Fire places number
# Lot Size
# 8450                       0
# 9600                       1
# 11250                      1
# 9550                       1
# 14260                      1

# %%
df_select.sort_index()
# Out:
#           Fire places number
# Lot Size
# 1300                       1
# 1477                       0
# 1491                       0
# 1526                       0
# 1533                       0
# ...                      ...
# 70761                      2
# 115149                     2
# 159000                     2
# 164660                     2
# 215245                     2
#
# [1460 rows x 1 columns]

# %%
df_select.sort_values(by ='Fire places number' )
# Out:
#           Fire places number
# Lot Size
# 8450                       0
# 7677                       0
# 12798                      0
# 4800                       0
# 9000                       0
# ...                      ...
# 13860                      3
# 63887                      3
# 13600                      3
# 12378                      3
# 10708                      3
#
# [1460 rows x 1 columns]

# %% [markdown]
# # Merge

# %%
df.head(3)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1

# %%
bathroom = df[['FullBath','HalfBath']]
bathroom.head(3)
# Out:
#    FullBath  HalfBath
# 0         2         1
# 1         2         0
# 2         2         1

# %%
area = df[['LotArea','GarageArea','HalfBath']]
area.head()
# Out:
#    LotArea  GarageArea  HalfBath
# 0     8450         548         1
# 1     9600         460         0
# 2    11250         608         1
# 3     9550         642         0
# 4    14260         836         1

# %%
area_1 = df[['LotArea','GarageArea']]
area_1.head()
pieces = [area_1, bathroom]
combine = pd.concat(pieces, sort=False, axis=1) # Must include axis =1, otherwise FullBath and HalfBath will be NaN
combine.head(3)
# Out:
#    LotArea  GarageArea  FullBath  HalfBath
# 0     8450         548         2         1
# 1     9600         460         2         0
# 2    11250         608         2         1

# %%
select = pd.merge(area, bathroom)
select.head(3)
# Out:
#    LotArea  GarageArea  HalfBath  FullBath
# 0     8450         548         1         2
# 1     8450         548         1         2
# 2     8450         548         1         2

# %%
area_1

# %% [markdown]
# # Regroup

# %%
data_group = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
   ....:                          'foo', 'bar', 'foo', 'foo'],
   ....:                    'B': ['one', 'one', 'two', 'three',
   ....:                          'two', 'two', 'one', 'three'],
   ....:                    'C': np.random.randn(8),
   ....:                    'D': np.random.randn(8)})

# %%
data_group.head()
# Out:
#      A      B         C         D
# 0  foo    one  2.434283 -1.467114
# 1  bar    one -0.047720  1.726215
# 2  foo    two -0.600154 -0.011827
# 3  bar  three -0.362675 -0.856737
# 4  foo    two -1.128459 -0.183931

# %%
data_group_1 = data_group.groupby(['B', 'A']).sum()
data_group_1
# Out:
#                   C         D
# B     A
# one   bar -0.047720  1.726215
#       foo  4.465395 -0.515680
# three bar -0.362675 -0.856737
#       foo  0.929960  0.090154
# two   bar  1.047710 -0.850873
#       foo -1.728613 -0.195758

# %%
#data_group_1.melt(id_vars=['B','A'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-35d07600bf86> in <module>()
# ----> 1 data_group_1.melt(id_vars=['B','A'])
#
# C:\Users\Peter\Anaconda3\lib\site-packages\pandas\core\frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level)
#    6513             var_name=var_name,
#    6514             value_name=value_name,
# -> 6515             col_level=col_level,
#    6516         )
#    6517
#
# C:\Users\Peter\Anaconda3\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#      50                     "The following 'id_vars' are not present"
#      51                     " in the DataFrame: {missing}"
# ---> 52                     "".format(missing=list(missing))
#      53                 )
#      54     else:
#
# ...

# %% [markdown]
# # Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))
   ....:

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
df_tri = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df_tri
# Out:
#                      A         B
# first second
# bar   one    -1.915946 -1.407680
#       two     0.568372  0.733203
# baz   one     1.303306  0.500422
#       two    -2.071630  0.510219
# foo   one    -0.300137 -0.013098
#       two    -0.783409  0.793668
# qux   one     1.751444 -1.731032
#       two     1.857944 -0.212791

# %%
df_tri_stack= df_tri.stack()
type(df_tri_stack)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # TimeSeries

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
rng[:5]
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.head()
# Out:
# 2012-01-01 00:00:00    355
# 2012-01-01 00:00:01    155
# 2012-01-01 00:00:02     98
# 2012-01-01 00:00:03    457
# 2012-01-01 00:00:04     34
# Freq: S, dtype: int32

# %%
len(ts)
# Out:
# 100

# %%
rng[-1]
# Out:
# Timestamp('2012-01-01 00:01:39', freq='S')

# %% [markdown]
# # Visualization

# %%
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
#df_select = df[['TotalBsmtSF','FullBath']]
import matplotlib.pyplot as plt
ax = df.plot.scatter(x = 'TotalBsmtSF', y= 'GarageArea',c='blue')

# %%
plt.scatter(x = df.TotalBsmtSF, y= df.GarageArea)
plt.show()

# %% [markdown]
# # Datetime Visualization

# %%
import pandas as pd
df = pd.read_csv('https://accounts.profunds.com/etfdata/ByFund/SH-historical_nav.csv')
df.head(10)
df.Date = df.Date.astype('str')
df['Date'] = pd.to_datetime(df.Date, format='%m/%d/%Y',errors='coerce')
i = 0
j = -1
#plt.plot_date(x = df.Date[:500], y= df['Shares Outstanding (000)'][:500])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot_date(x = df.Date[i:j], y= df['Shares Outstanding (000)'][i:j], color = 'r')
ax2.plot_date(x = df.Date[i:j], y= 1/(df['NAV'][i:j]))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5/2)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('https://accounts.profunds.com/etfdata/ByFund/SH-historical_nav.csv', parse_dates=[0]) 
i = (df.index[df.Date == '2020-05-01'])[0]
j = (df.index[df.Date == '2019-05-01'])[0]
print (i,j)
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot_date(x = df.Date[i:j], y= df['Shares Outstanding (000)'][i:j], color = 'r', label = 'Share Outstanding (000)')
ax2.plot_date(x = df.Date[i:j], y= 1/(df['NAV'][i:j]), label = '1/NAV of SH')
ax1.set_xlabel('Date')
ax1.set_ylabel('Shares Outstanding (000)')
ax2.set_ylabel('1/NAV of SH')
ax1.set_title('SH')
ax1.legend(loc = 0)
ax2.legend(loc = 0)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5/2)
plt.show()
# Out:
# 5 258
